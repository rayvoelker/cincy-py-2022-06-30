# %% [markdown]
# <a href="https://colab.research.google.com/github/rayvoelker/cincy-py-2022-06-30/blob/main/2022_06_39_cincy_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Thursday, June 30, 2022
#
# ## CincyPy Reconnect!
#
# <img src="https://raw.githubusercontent.com/rayvoelker/cincy-py-2022-06-30/main/cincy_py.jpg">
#
# Ray Voelker | ray.voelker@gmail.com
#
# ### Data Vis
#
# 1. Hamiltion County Ohio Board of Elections -- Voter lists:
#    - https://votehamiltoncountyohio.gov/campaign-media/voter-lists/
#
# 1. U.S. Census Bureau -- The 2020 ZIP Code Tabulation Areas (ZCTAs) (Polygons With All Geocodes)
#    - https://www.census.gov/geographies/mapping-files/2020/geo/tiger-line-file.html

# %%
# NOTE: pandas, and altair are already included with the base colab image...
# !pip install -U pandas --quiet
# !pip install -U altair --quiet

# !pip install -U duckdb --quiet

import pandas as pd
import altair as alt

from google.colab import data_table
# enable the formatter for more functionality with tabular data
data_table.enable_dataframe_formatter()

# %%
# get the current Hamilton County registerd voter list ...
# downloaded and compressed from here: https://votehamiltoncountyohio.gov/campaign-media/voter-lists/

# !wget --quiet https://github.com/rayvoelker/cincy-py-2022-06-30/raw/main/VoterListExport-20220627-no.tar.xz --output-document=VoterListExport.tar.xz

# %%
import duckdb

# connect to an in-memory database
con = duckdb.connect()

df = pd.read_csv(
    "VoterListExport.tar.xz", 
    parse_dates=['RegisteredDate'],
    low_memory=False
)

# %%
# take a look at the columns in the voter list dataframe ...
df.columns
# Out:
# Index(['VoterListExport-20220627-no.csv', 'PrecinctNum', 'PrecinctSplit',
#        'PrecinctName', 'RegisteredDate', 'FirstName', 'MiddleName', 'LastName',
#        'SuffixName', 'MiddleName.1', 'SuffixName.1', 'Phone', 'Status',
#        'PartyCode', 'BirthYear', 'AddressPreDirectional', 'AddressNumber',
#        'AddressFraction', 'AddressStreet', 'AddressSuffix', 'AddressOther',
#        'CityName', 'AddressZip', 'Congress', 'Senate', 'House', 'Judicial',
#        'School', 'CountySchool', 'VocationalSchool', 'RegistrationDate',
#        'GENERAL_NOV_2022', 'PRIMARY_AUG_2022', 'PRIMARY_MAY_2022',
#        'GENERAL_NOV_2021', 'GENERAL_NOV_2020', 'PRIMARY_MARCH_2020',
#        'GENERAL_NOV_2019', 'GENERAL_NOV_2018', 'PRIMARY_MAY_2018',
#        'GENERAL_NOV_2017'],
#       dtype='object')

# %%
# casually download ~500 MB of shape data ... 
# we'll get to this later ... 
# !wget --quiet https://www2.census.gov/geo/tiger/TIGER2021/ZCTA520/tl_2021_us_zcta520.zip --output-document=tl_2021_us_zcta520.zip

# if the above doesn't work, the file is also in this repo:
# !wget --quiet https://github.com/rayvoelker/cincy-py-2022-06-30/raw/main/tl_2021_us_zcta520.tar.xz --output-document=tl_2021_us_zcta520.tar.xz

# %%
# DuckDB allows us to efficently run SQL on the Pandas DataFrame!
# https://duckdb.org/2021/05/14/sql-on-pandas.html
result_df = con.execute("""\
  SELECT
    AddressNumber,
    AddressStreet,
    AddressSuffix,
    CityName,
    AddressZip,
    BirthYear,
    PartyCode,
    PrecinctNum,
    PrecinctName,
    RegisteredDate,
    strftime('%Y', RegisteredDate) as reg_year, 
    Status, 
    PRIMARY_MAY_2022
  FROM
    df
  ORDER BY RANDOM()
  LIMIT 1000
  """
).df()

result_df
# Out:
#      AddressNumber      AddressStreet AddressSuffix    CityName  AddressZip  \
# 0           1725.0            CLENEAY           AVE  CINCINNATI     45212.0
# 1            320.0        GLENSPRINGS            DR  CINCINNATI     45246.0
# 2           9101.0             WINTON            RD  CINCINNATI     45231.0
# 3          11834.0           COLERAIN           AVE  CINCINNATI     45252.0
# 4            654.0          FLAGSTAFF            DR  CINCINNATI     45215.0
# ..             ...                ...           ...         ...         ...
# 995         2012.0  WESTWOOD NORTHERN          BLVD  CINCINNATI     45225.0
# 996         7825.0           AFFINITY            PL  CINCINNATI     45231.0
# 997          945.0            FINDLAY            ST  CINCINNATI     45214.0
# 998           82.0              JACOB            DR    HARRISON     45030.0
# 999          982.0          CLEVELAND           AVE  CINCINNATI     45229.0
#
#      BirthYear PartyCode  PrecinctNum     PrecinctName RegisteredDate  \
# 0       1998.0       NON       4411.0      NORWOOD 1-A     2020-11-03
# 1       1956.0       NON       5207.0     SPRINGDALE G     1989-07-17
# 2       1937.0       NON       8726.0    SPRINGFIELD Z     1989-07-17
# 3       1956.0       NON       5901.0       COLERAIN A     2014-11-04
# 4       1976.0       NON       5305.0        WYOMING E     1995-10-14
# ..         ...       ...          ...              ...            ...
# 995     1930.0       NON       2203.0  CINCINNATI 22-C     1989-07-17
# 996     1948.0       DEM       4111.0   MT HEALTHY 1-A     1989-07-17
# 997     1975.0       NON       1801.0  CINCINNATI 18-A     2020-10-05
# 998     1946.0       NON       6402.0         CROSBY B     1992-03-09
# 999     1967.0       NON       1307.0  CINCINNATI 13-G     2012-09-24
#
#     reg_year Status PRIMARY_MAY_2022
# 0       2020      A              NaN
# 1       1989      A              NaN
# 2       1989      I              NaN
# 3       2014      A              NaN
# 4       1995      A              NaN
# ..       ...    ...              ...
# 995     1989      I              NaN
# 996     1989      A            P-DEM
# 997     2020      A              NaN
# 998     1992      A              NaN
# 999     2012      I              NaN
#
# [1000 rows x 13 columns]

# %%
# What is the voter status by year of registration?
# Query:
#
result_df = con.execute("""\
  SELECT
  strftime('%Y', RegisteredDate) as 'Registraion Year', 
  Status, 
  count(*) as count_voters
  FROM
  df
  WHERE
  'Registraion Year' IS NOT NULL
  AND 'Status' IS NOT NULL
  GROUP BY 1,2
  HAVING count(*) > 1
  ORDER BY 3 DESC
""").df()

result_df
# Out:
#    Registraion Year Status  count_voters
# 0              1989      A        103105
# 1              2020      A         42222
# 2              2016      A         27754
# 3              2004      A         22860
# 4              2018      A         21819
# ..              ...    ...           ...
# 71             1986      A            14
# 72             1967      A             3
# 73             1970      I             2
# 74             1988      I             2
# 75             1985      A             2
#
# [76 rows x 3 columns]

# %%
# What is the voter status by year of registration?
# Chart:
#
alt.Chart(result_df).mark_bar().encode(
    x=alt.X('count_voters', ), # sort='-y'
    y=alt.Y('Registraion Year', sort='-x'), # sort='-x'
    tooltip=['Registraion Year', 'count_voters', 'Status'],
    color=alt.Color(
        'Status',
        scale=alt.Scale(
            # https://vega.github.io/vega/docs/schemes/
            # scheme='set1'
            scheme='set2'
        )
    )
).properties(
    title=''
).configure_title(
    # fontSize=20,
    anchor='start',
)
# Out:
# alt.Chart(...)

# %%
# What are the party codes in the data?
result_df = con.execute("""\
  SELECT
  lower(PartyCode) as party_code,
  count(*) as count_voters
  FROM
  df
  WHERE
  PartyCode IS NOT NULL
  GROUP BY 
  1
  ORDER BY 2 DESC
""").df()

result_df
# Out:
#   party_code  count_voters
# 0        non        431157
# 1        dem         85813
# 2        rep         72755
# 3        lib           100
# 4          u             1
# 5        con             1

# %%
# What is the voter status by PartyCode?
# Query:
#
result_df = con.execute("""\
  SELECT
  -- strftime('%Y', RegisteredDate) as 'Registraion Year',
  lower(PartyCode) as party_code,
  -- CASE PartyCode
  --    WHEN 'non' THEN 'NON'
  --    ELSE PartyCode
  --END as PartyCode,
  -- 'FirstName', 'MiddleName', 'LastName', 'SuffixName',
  -- 'MiddleName.1', 'SuffixName.1', 'Phone', 
  Status, 
  count(*) as count_voters
  FROM
  df
  WHERE
  lower(PartyCode) IN (
    SELECT
    lower(PartyCode) as party_code
    FROM
    df
    WHERE
    PartyCode IS NOT NULL
    GROUP BY 
    1
    HAVING count(*) >= 100
  )
  GROUP BY 
  1,2
""").df()

result_df
# Out:
#    party_code Status  count_voters
# 0         non      I        109132
# 1         non      A        321940
# 2         dem      A         84595
# 3         rep      A         72456
# 4         rep      I           294
# 5         dem      I          1210
# 6         lib      A            98
# 7         dem      M             8
# 8         non      M            85
# 9         rep      M             5
# 10        lib      I             2

# %%
# What is the voter status by PartyCode?
# Chart:
#
alt.Chart(result_df).mark_bar().encode(
    x=alt.X('count_voters', ),
    y=alt.Y('party_code', sort='-x'),
    tooltip=['party_code', 'count_voters', 'Status'],
    color=alt.Color(
        'Status',
        scale=alt.Scale(
            # https://vega.github.io/vega/docs/schemes/
            scheme='dark2'
        )
    )
).properties(
    title='Voter Status by PartyCode'
).configure_title(
    # fontSize=20,
    anchor='middle',
)
# Out:
# alt.Chart(...)

# %%
# What percentage of registered voters voted in the 2022 Primary Election?

# Query:
#
result_df = con.execute("""\
  WITH count_data as (
    SELECT
    PRIMARY_MAY_2022,
    count(*) as count_voters
    from
    df
    GROUP BY 1
  )
  SELECT
  PRIMARY_MAY_2022,
  ROUND(
    ((count_voters * 1.0 ) / (SELECT SUM(count_voters) FROM count_data)) * 100.0, 
    2
  ) as pct
  FROM
  count_data
""").df()

result_df
# Out:
#   PRIMARY_MAY_2022    pct
# 0              NaN  83.37
# 1            P-DEM   5.41
# 2            P-REP   8.42
# 3            A-REP   1.09
# 4            A-DEM   1.56
# 5            P-NON   0.13
# 6            A-NON   0.02

# %%
# What percentage of registered voters voted in the 2022 Primary Election?

alt.Chart(result_df).mark_bar().encode(
    x=alt.X('pct', ),
    # y=alt.Y('party_code', sort='-x'),
    tooltip=['PRIMARY_MAY_2022', 'pct',],
    color=alt.Color(
        'PRIMARY_MAY_2022',
        scale=alt.Scale(
            # https://vega.github.io/vega/docs/schemes/
            scheme='accent'
        )
    )
).properties(
    title='Percent Voters Voting in PRIMARY_MAY_2022',
    width=600,
    # height=300
).configure_title(
    # fontSize=20,
    anchor='middle',
)
# Out:
# alt.Chart(...)

# %%
result_df = con.execute("""\
  SELECT
    AddressZip,
    count(PRIMARY_MAY_2022) AS count_voters
  FROM
    df
  WHERE
    PRIMARY_MAY_2022 IS NOT NULL
    AND AddressZip IS NOT NULL
  GROUP BY 1
""").df()

result_df
# Out:
#     AddressZip  count_voters
# 0      45231.0          5046
# 1      45215.0          4112
# 2      45237.0          2374
# 3      45224.0          2787
# 4      45246.0          1747
# 5      45209.0          1187
# 6      45244.0          2716
# 7      45202.0          1790
# 8      45241.0          2832
# 9      45208.0          3621
# 10     45249.0          1893
# 11     45248.0          3234
# 12     45213.0          1865
# 13     45233.0          2533
# 14     45230.0          4192
# 15     45255.0          2569
# 16     45243.0          3206
# 17     45252.0           863
# 18     45227.0          2269
# 19     45240.0          2740
# 20     45030.0          2568
# 21     45238.0          4278
# 22     45002.0          1871
# 23     45236.0          3392
# 24     45204.0           292
# 25     45140.0          2622
# 26     45218.0           788
# 27     45226.0           907
# 28     45219.0           559
# 29     45212.0          1678
# 30     45220.0          1504
# 31     45242.0          4160
# 32     45239.0          2448
# 33     45217.0           628
# 34     45251.0          2073
# 35     45223.0          1489
# 36     45211.0          3014
# 37     45206.0          1310
# 38     45052.0           769
# 39     45205.0           777
# 40     45001.0            41
# 41     45174.0           405
# 42     45225.0           207
# 43     45214.0           327
# 44     45216.0           632
# 45     45207.0           453
# 46     45111.0            78
# 47     45232.0           243
# 48     45051.0            58
# 49     45033.0            19
# 50     45041.0             7
# 51     45013.0             1
# 52     45150.0             3
# 53     45247.0          3784
# 54     45229.0           994
# 55     45203.0           150

# %%
# !pip install -U geopandas --quiet
# !pip install -U folium matplotlib mapclassify --quiet
# !pip install -U pyshp
# !pip install -U shapely
# !pip install -U descartes
# !pip install -U osmnx

# %%
import pandas as pd
import geopandas as gpd
import duckdb

# connect to an in-memory database
con = duckdb.connect()

df = pd.read_csv(
    "VoterListExport.tar.xz", 
    parse_dates=['RegisteredDate'],
    low_memory=False
)

gdf_org = gpd.read_file('tl_2021_us_zcta520.zip')

# %%
result_df = con.execute("""\
  SELECT
    cast(AddressZip as INTEGER) as AddressZip,
    count(PRIMARY_MAY_2022) AS count_voters
  FROM
    df
  WHERE
    PRIMARY_MAY_2022 IS NOT NULL
    AND AddressZip IS NOT NULL
  GROUP BY 1
  HAVING count(PRIMARY_MAY_2022) >= 5
""").df()


# merge the above dataframe and the dataframe containing our 
# GEOID20
result_df.rename(columns={"AddressZip": "GEOID20"}, inplace=True)
# convert the column to string so we can do our merge
result_df['GEOID20'] = result_df['GEOID20'].astype(str)

gdf = gdf_org.merge(result_df, on='GEOID20', how='inner')

gdf[
    gdf['GEOID20'].isin(
      [str(zip_code) for zip_code in result_df['GEOID20']]
    )
].explore(
    "count_voters",
    cmap="YlGn"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffa7f65771f9992a8dfced07fc7f78e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffa7f65771f9992a8dfced07fc7f78e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ffa7f65771f9992a8dfced07fc7f78e2 = L.map(
#                 &quot;map_ffa7f65771f9992a8dfced07fc7f78e2&quot;,
#                 {
#                     center: [39.169636, -84.490443],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ffa7f65771f9992a8dfced07fc7f78e2);
#
#
#
#
#
#             var tile_layer_6c452b64bf0e0ddbfe29fd7251415c25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ffa7f65771f9992a8dfced07fc7f78e2);
#
#
#             map_ffa7f65771f9992a8dfced07fc7f78e2.fitBounds(
#                 [[39.021534, -84.820305], [39.317738, -84.160581]],
#                 {}
#             );
#
#
#         function geo_json_bf2228381bdcf7961f910af05cb02bc1_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#fbfed2&quot;, &quot;fillColor&quot;: &quot;#fbfed2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#edf8b1&quot;, &quot;fillColor&quot;: &quot;#edf8b1&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#8ed082&quot;, &quot;fillColor&quot;: &quot;#8ed082&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#b5e092&quot;, &quot;fillColor&quot;: &quot;#b5e092&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#d6efa2&quot;, &quot;fillColor&quot;: &quot;#d6efa2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#c9e99c&quot;, &quot;fillColor&quot;: &quot;#c9e99c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#e6f5ac&quot;, &quot;fillColor&quot;: &quot;#e6f5ac&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#9fd788&quot;, &quot;fillColor&quot;: &quot;#9fd788&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fafdc9&quot;, &quot;fillColor&quot;: &quot;#fafdc9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#3fa85b&quot;, &quot;fillColor&quot;: &quot;#3fa85b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#ffffe4&quot;, &quot;fillColor&quot;: &quot;#ffffe4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;50&quot;:
#                     return {&quot;color&quot;: &quot;#f0f9b4&quot;, &quot;fillColor&quot;: &quot;#f0f9b4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#f8fcbe&quot;, &quot;fillColor&quot;: &quot;#f8fcbe&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#fbfdcf&quot;, &quot;fillColor&quot;: &quot;#fbfdcf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#ddf2a6&quot;, &quot;fillColor&quot;: &quot;#ddf2a6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#66bd70&quot;, &quot;fillColor&quot;: &quot;#66b

# %%
# Hamilton County Ohio Voters in the 2020 General Elections

result_df = con.execute("""\
  SELECT
    cast(AddressZip as INTEGER) as AddressZip,
    count(GENERAL_NOV_2020) AS count_voters
  FROM
    df
  WHERE
    GENERAL_NOV_2020 IS NOT NULL
    AND AddressZip IS NOT NULL
  GROUP BY 1
  HAVING count(GENERAL_NOV_2020) >= 5
""").df()


# merge the above dataframe and the dataframe containing our 
# GEOID20
result_df.rename(columns={"AddressZip": "GEOID20"}, inplace=True)
# convert the column to string so we can do our merge
result_df['GEOID20'] = result_df['GEOID20'].astype(str)

gdf = gdf_org.merge(result_df, on='GEOID20', how='inner')

gdf[
    gdf['GEOID20'].isin(
      [str(zip_code) for zip_code in result_df['GEOID20']]
    )
].explore(
    "count_voters",
    cmap="YlGn"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91eebd73d517aab7951086c7e9a64150 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91eebd73d517aab7951086c7e9a64150&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_91eebd73d517aab7951086c7e9a64150 = L.map(
#                 &quot;map_91eebd73d517aab7951086c7e9a64150&quot;,
#                 {
#                     center: [39.287423000000004, -84.490443],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_91eebd73d517aab7951086c7e9a64150);
#
#
#
#
#
#             var tile_layer_63f7855da809b694f0488a7ff1138675 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_91eebd73d517aab7951086c7e9a64150);
#
#
#             map_91eebd73d517aab7951086c7e9a64150.fitBounds(
#                 [[39.021534, -84.820305], [39.553312, -84.160581]],
#                 {}
#             );
#
#
#         function geo_json_695a97f2397b8d8d75899676e4cbf070_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#fafdc9&quot;, &quot;fillColor&quot;: &quot;#fafdc9&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;33&quot;:
#                     return {&quot;color&quot;: &quot;#f3fab6&quot;, &quot;fillColor&quot;: &quot;#f3fab6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#83cb7d&quot;, &quot;fillColor&quot;: &quot;#83cb7d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#a4d98a&quot;, &quot;fillColor&quot;: &quot;#a4d98a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#d7efa2&quot;, &quot;fillColor&quot;: &quot;#d7efa2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#cfec9e&quot;, &quot;fillColor&quot;: &quot;#cfec9e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#dcf1a5&quot;, &quot;fillColor&quot;: &quot;#dcf1a5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#7fc97c&quot;, &quot;fillColor&quot;: &quot;#7fc97c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fafdcc&quot;, &quot;fillColor&quot;: &quot;#fafdcc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#feffe1&quot;, &quot;fillColor&quot;: &quot;#feffe1&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#f9fdc4&quot;, &quot;fillColor&quot;: &quot;#f9fdc4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#e6f5ac&quot;, &quot;fillColor&quot;: &quot;#e6f5ac&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;37&quot;:
#                     return {&quot;color&quot;: &quot;#f7fcbc&quot;, &quot;fillColor&quot;: &quot;#f7fcbc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#d2eda0&quot;, &quot;fillColor&quot;: &quot;#d2eda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#4eb163&quot;, &quot;fillColor&quot;: &quot;#4eb163&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
#                     return {&

# %%
result_df = con.execute("""\
  SELECT
  -- PRIMARY_MARCH_2016,
  lower(PartyCode) as PartyCode,
  cast(AddressZip as INTEGER) as AddressZip,
  count(*) AS count_voters
  FROM
  df
  WHERE
  lower(PartyCode) = 'rep'
  AND AddressZip is not null
  GROUP BY 1,2

""").df()

# merge the above dataframe and the dataframe containing our 
# GEOID20
result_df.rename(columns={"AddressZip": "GEOID20"}, inplace=True)
# convert the column to string so we can do our merge
result_df['GEOID20'] = result_df['GEOID20'].astype(str)

gdf = gdf_org.merge(result_df, on='GEOID20', how='inner')

gdf[
    gdf['GEOID20'].isin(
      [str(zip_code) for zip_code in result_df['GEOID20']]
    )
].explore(
    "count_voters",
    cmap="Reds"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cadb5ce723996a70e0406b0dc180b8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cadb5ce723996a70e0406b0dc180b8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9cadb5ce723996a70e0406b0dc180b8c = L.map(
#                 &quot;map_9cadb5ce723996a70e0406b0dc180b8c&quot;,
#                 {
#                     center: [39.287423000000004, -84.490443],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9cadb5ce723996a70e0406b0dc180b8c);
#
#
#
#
#
#             var tile_layer_d79a0e9987a52678db1a6060c5d60159 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9cadb5ce723996a70e0406b0dc180b8c);
#
#
#             map_9cadb5ce723996a70e0406b0dc180b8c.fitBounds(
#                 [[39.021534, -84.820305], [39.553312, -84.160581]],
#                 {}
#             );
#
#
#         function geo_json_60f87eada21a94c5b9952169ee1f8411_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#ffede5&quot;, &quot;fillColor&quot;: &quot;#ffede5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fcc2aa&quot;, &quot;fillColor&quot;: &quot;#fcc2aa&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fcaf93&quot;, &quot;fillColor&quot;: &quot;#fcaf93&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#fdd5c4&quot;, &quot;fillColor&quot;: &quot;#fdd5c4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;49&quot;:
#                     return {&quot;color&quot;: &quot;#fee7db&quot;, &quot;fillColor&quot;: &quot;#fee7db&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#ffebe2&quot;, &quot;fillColor&quot;: &quot;#ffebe2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#ffefe8&quot;, &quot;fillColor&quot;: &quot;#ffefe8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#fb7a5a&quot;, &quot;fillColor&quot;: &quot;#fb7a5a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fee8dd&quot;, &quot;fillColor&quot;: &quot;#fee8dd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#e53228&quot;, &quot;fillColor&quot;: &quot;#e53228&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;34&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;#fff4ee&quot;, &quot;fillColor&quot;: &quot;#fff4ee&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;19&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;#fedfd0&quot;, &quot;fillColor&quot;: &quot;#fedfd0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#fff0e8&quot;, &quot;fillColor&quot;: &quot;#fff0e8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#fff2eb&quot;, &quot;fillColor&quot;: &quot;#fff2eb&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#fedecf&quot;, &quot;fillColor&quot;: &quot;#fedecf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;: case &quo

# %%
result_df = con.execute("""\
  SELECT
  -- PRIMARY_MARCH_2016,
  lower(PartyCode) as PartyCode,
  cast(AddressZip as INTEGER) as AddressZip,
  count(*) AS count_voters
  FROM
  df
  WHERE
  lower(PartyCode) = 'dem'
  AND AddressZip is not null
  GROUP BY 1,2

""").df()

# merge the above dataframe and the dataframe containing our 
# GEOID20
result_df.rename(columns={"AddressZip": "GEOID20"}, inplace=True)
# convert the column to string so we can do our merge
result_df['GEOID20'] = result_df['GEOID20'].astype(str)

gdf = gdf_org.merge(result_df, on='GEOID20', how='inner')

gdf[
    gdf['GEOID20'].isin(
      [str(zip_code) for zip_code in result_df['GEOID20']]
    )
].explore(
    "count_voters",
    cmap="Blues"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3dba955a7e9b4ecf29580d1918f451eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3dba955a7e9b4ecf29580d1918f451eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3dba955a7e9b4ecf29580d1918f451eb = L.map(
#                 &quot;map_3dba955a7e9b4ecf29580d1918f451eb&quot;,
#                 {
#                     center: [39.169636, -84.490443],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3dba955a7e9b4ecf29580d1918f451eb);
#
#
#
#
#
#             var tile_layer_f239fbca97eda526662c49ce5d0f3400 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3dba955a7e9b4ecf29580d1918f451eb);
#
#
#             map_3dba955a7e9b4ecf29580d1918f451eb.fitBounds(
#                 [[39.021534, -84.820305], [39.317738, -84.160581]],
#                 {}
#             );
#
#
#         function geo_json_fc33a647bcb9aecc3fddcac5f7f63838_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;8&quot;: case &quot;39&quot;:
#                     return {&quot;color&quot;: &quot;#edf4fc&quot;, &quot;fillColor&quot;: &quot;#edf4fc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#eaf2fb&quot;, &quot;fillColor&quot;: &quot;#eaf2fb&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#5ba3d0&quot;, &quot;fillColor&quot;: &quot;#5ba3d0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#72b2d8&quot;, &quot;fillColor&quot;: &quot;#72b2d8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#95c5df&quot;, &quot;fillColor&quot;: &quot;#95c5df&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#6caed6&quot;, &quot;fillColor&quot;: &quot;#6caed6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#97c6df&quot;, &quot;fillColor&quot;: &quot;#97c6df&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#abd0e6&quot;, &quot;fillColor&quot;: &quot;#abd0e6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#a0cbe2&quot;, &quot;fillColor&quot;: &quot;#a0cbe2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#f6faff&quot;, &quot;fillColor&quot;: &quot;#f6faff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;#e7f1fa&quot;, &quot;fillColor&quot;: &quot;#e7f1fa&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#cee0f2&quot;, &quot;fillColor&quot;: &quot;#cee0f2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#dfebf7&quot;, &quot;fillColor&quot;: &quot;#dfebf7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;: case &quot;53&quot;:
#                     return {&quot;color&quot;: &quot;#b9d6ea&quot;, &quot;fillColor&quot;: &quot;#b9d6ea&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;: case &quot;43&quot;:
#                     return {&quot;color&quot;: &quot;#2272b6&quot;, &quot;fillColor&quot;: &quot;#2272b6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
